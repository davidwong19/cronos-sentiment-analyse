# %%
import pandas as pd
df = pd.read_csv('reviews.csv')
pd.set_option("display.max_rows", None)
df
# Out:
#                                   company        date  \
# 0                            your oxygen   14/02/2015
# 1                              ARXUS INC.  29/04/2018
# 2                              ARXUS INC.  29/04/2017
# 3                              ARXUS INC.  29/04/2018
# 4                                  ASTENA  2021-10-29
# 5                                  ASTENA  29/07/2021
# 6                                  ASTENA  29/04/2018
# 7                                  Axeasy  29/04/2018
# 8                           Cronos Europa  29/04/2019
# 9                           Cronos Europa  29/04/2021
# 10                          Cronos Europa  29/04/2018
# 11                          Cronos Europa  29/04/2017
# 12                          Cronos Europa  29/04/2021
# 13                          Cronos Europa  29/04/2018
# 14                          Cronos Europa  29/04/2018
# 15                          Cronos Europa  29/04/2020
# ...
