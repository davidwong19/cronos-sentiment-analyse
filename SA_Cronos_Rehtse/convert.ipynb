# %% [markdown]
# **This is just a notebook that will allow me to drop te '_id' from the latest dataset, so I can set an index**

# %%
import pandas as pd

# %%
df = pd.read_csv('../Reviews_merged/Reviews_Cronos.csv')
df
# Out:
#                           _id       company        date  \
# 0    626bd53ad10793287c3acc02  your oxygen   14/02/2015
# 1    626bd53ad10793287c3acc03    ARXUS INC.  29/04/2018
# 2    626bd53ad10793287c3acc04    ARXUS INC.  29/04/2017
# 3    626bd53ad10793287c3acc05    ARXUS INC.  29/04/2018
# 4    626bd53ad10793287c3acc06        ASTENA  2021-10-29
# ..                        ...           ...         ...
# 375  626baab5206405d41e6ba3ea        cronos  13/04/2022
# 376  6271024821a1d929e59e45a4        cronos  04/05/2022
# 377  6271024821a1d929e59e45a5        cronos  04/05/2022
# 378  6271024821a1d929e59e45a6        cronos  04/05/2022
# 379  6271024821a1d929e59e45a7        cronos  31/03/2021
#
#                                                opinion  rating        source
# 0    December 2014 ben ik bij Your Oxygen ingeschre...     4.0      facebook
# 1                    Custom professional IT solutions.     5.0        google
# ...

# %%
df = df.drop(columns='_id')

# %%
df.to_csv('Reviews_Cronos.csv', mode='a', header=True,index=True)
