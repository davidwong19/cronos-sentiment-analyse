# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Rehts\Documents\Repositories\cronos-sentiment-analyse\MAIN\final_reviews.csv')
df.head()
# Out:
#    id      company                                            opinion  \
# 0   0  your oxygen  December 2014 ben ik bij Your Oxygen ingeschre...
# 1   1   ARXUS INC.                  Custom professional IT solutions.
# 2   2   ARXUS INC.                         Belgian cloud at its best!
# 3   3   ARXUS INC.  Fast growing company with motivated people. Kn...
# 4   4       ASTENA                                                 Ok
#
#          date  rating    source   score sentiment
# 0  14/02/2015       4  facebook  0.4574  positive
# 1  29/04/2018       5    google  0.1779  positive
# 2  29/04/2017       5    google  0.6696  positive
# 3  29/04/2018       5    google  0.6114  positive
# 4  2021/10/29       5    google  0.2960  positive

# %%
df = df.drop(['id'], axis=1)
df.head()
# Out:
#        company                                            opinion        date  \
# 0  your oxygen  December 2014 ben ik bij Your Oxygen ingeschre...  14/02/2015
# 1   ARXUS INC.                  Custom professional IT solutions.  29/04/2018
# 2   ARXUS INC.                         Belgian cloud at its best!  29/04/2017
# 3   ARXUS INC.  Fast growing company with motivated people. Kn...  29/04/2018
# 4       ASTENA                                                 Ok  2021/10/29
#
#    rating    source   score sentiment
# 0       4  facebook  0.4574  positive
# 1       5    google  0.1779  positive
# 2       5    google  0.6696  positive
# 3       5    google  0.6114  positive
# 4       5    google  0.2960  positive

# %%
df.drop_duplicates(subset=None, inplace=True)
df.to_csv('final_reviewsV2.csv', index=True)
