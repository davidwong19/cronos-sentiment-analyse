# %%
import pandas as pd
df = pd.read_csv('reviews_cronos_score.csv')
df.head(5)
# Out:
#                         _id       company        date  \
# 0  626bd53ad10793287c3acc02  your oxygen   14/02/2015
# 1  626bd53ad10793287c3acc03    ARXUS INC.  29/04/2018
# 2  626bd53ad10793287c3acc04    ARXUS INC.  29/04/2017
# 3  626bd53ad10793287c3acc05    ARXUS INC.  29/04/2018
# 4  626bd53ad10793287c3acc06        ASTENA  2021-10-29
#
#                                              opinion  rating    source  \
# 0  December 2014 ben ik bij Your Oxygen ingeschre...     4.2  facebook
# 1                  Custom professional IT solutions.     5.0    google
# 2                         Belgian cloud at its best!     5.0    google
# 3   Fast growing company with motivated people. K...     5.0    google
# 4                                                 Ok     5.0    google
#
#   sentiment_score     score rating_user
# 0        positive  0.033333    positive
# 1        positive  0.100000    positive
# 2        positive  1.000000    positive
# 3        positive  0.250000    positive
# ...

# %%
df['rating'].replace('.',',').astype(float)
# Out:
# 0      4.2
# 1      5.0
# 2      5.0
# 3      5.0
# 4      5.0
# 5      1.0
# 6      5.0
# 7      5.0
# 8      5.0
# 9      5.0
# 10     1.0
# 11     5.0
# 12     1.0
# 13     5.0
# 14     5.0
# 15     5.0
# 16     4.0
# 17     5.0
# 18     5.0
# 19     5.0
# 20     2.0
# 21     4.0
# 22     5.0
# 23     5.0
# 24     5.0
# 25     4.0
# 26     2.0
# 27     4.0
# 28     5.0
# 29     5.0
# 30     5.0
# 31     5.0
# 32     5.0
# 33     5.0
# 34     5.0
# 35     5.0
# 36     5.0
# 37     5.0
# 38     5.0
# 39     5.0
# 40     5.0
# 41     5.0
# 42     5.0
# 43     3.0
# 44     1.0
# 45     5.0
# 46     2.0
# 47     5.0
# 48     5.0
# 49     5.0
# 50     5.0
# 51     2.0
# 52     3.0
# 53     5.0
# 54     5.0
# 55     5.0
# 56     2.0
# 57     5.0
# 58     5.0
# 59     1.0
# 60     3.0
# 61     4.0
# 62     3.0
# 63     1.0
# 64     4.0
# 65     4.0
# 66     5.0
# 67     4.0
# 68     5.0
# 69     5.0
# 70     4.0
# 71     5.0
# 72     3.0
# 73     4.0
# 74     5.0
# 75     5.0
# ...

# %%
df.dtypes
# Out:
# _id                 object
# company             object
# date                object
# opinion             object
# rating             float64
# source              object
# sentiment_score     object
# score              float64
# rating_user         object
# dtype: object

# %%
df.sample(5)
# Out:
#                           _id               company        date  \
# 92   626bd74f2a51ba6a4ed5c50b             HeadCount  03/08/2020
# 75   626bd74f2a51ba6a4ed5c4fa                Flexso  20/01/2022
# 267  626a963dad878d7a61f7ef13                   NaN  21/07/2019
# 377  6271024821a1d929e59e45a5                   NaN  04/05/2022
# 44   626bd6de2a51ba6a4ed5c4a6  Cronos International  23/03/2019
#
#                                                opinion  rating        source  \
# 92   - Trust and good relationships with workers an...     5.0     glassdoor
# 75   Listening box of its super interesting employe...     5.0     glassdoor
# 267  Good atmosphere, many initiatives for employee...     4.0     glassdoor
# 377  That was not the case with my current intermed...     NaN  beyondgaming
# 44   No advantage for this employer, the Helpdesk S...     1.0     glassdoor
#
#     sentiment_score     score rating_user
# 92         positive  0.365625    positive
# ...
